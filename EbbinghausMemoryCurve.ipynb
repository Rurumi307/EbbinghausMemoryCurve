# %%
import datetime
import pandas as pd

planName = ''
listName = 'L'
startDate = datetime.date(2023,8,30)
listPerDay = 1
totalList = 91
reverse = False
skip_date_list = ["2023-09-29", "2023-10-09", "2023-10-10", "2024-01-01"]

df = pd.DataFrame()
cnt = 0
while True:
    while (
        startDate.strftime("%w") == '0'
        or startDate.strftime("%w") == '6'
        or str(startDate) in skip_date_list
    ):
        startDate = startDate + datetime.timedelta(days=1)
    cnt += 1
    date_str = startDate.strftime("%B %#d, %Y")
    list_value = listName + str(cnt).zfill(2)
    
    df = pd.concat([df, pd.DataFrame([{"Name": list_value, "Date": date_str, ""=[] }])], ignore_index=True)
    startDate = startDate + datetime.timedelta(days=1)
    if cnt == totalList:
        break

# %%
df
# Out:
#    Name               Date
# 0   L01    August 30, 2023
# 1   L02    August 31, 2023
# 2   L03  September 1, 2023
# 3   L04  September 4, 2023
# 4   L05  September 5, 2023
# ..  ...                ...
# 86  L87    January 3, 2024
# 87  L88    January 4, 2024
# 88  L89    January 5, 2024
# 89  L90    January 8, 2024
# 90  L91    January 9, 2024
#
# [91 rows x 2 columns]

# %%
df
# Out:
#    Name               Date
# 0   L01    August 30, 2023
# 1   L02    August 31, 2023
# 2   L03  September 1, 2023
# 3   L04  September 4, 2023
# 4   L05  September 5, 2023
# ..  ...                ...
# 86  L87    January 3, 2024
# 87  L88    January 4, 2024
# 88  L89    January 5, 2024
# 89  L90    January 8, 2024
# 90  L91    January 9, 2024
#
# [91 rows x 2 columns]

# %%
list_dict = dict(zip(df['Name'], df['Date']))
date_dict = dict(zip(df['Date'], []))

# %%
date_dict
# Out:
# {'August 30, 2023': 'L01',
#  'August 31, 2023': 'L02',
#  'September 1, 2023': 'L03',
#  'September 4, 2023': 'L04',
#  'September 5, 2023': 'L05',
#  'September 6, 2023': 'L06',
#  'September 7, 2023': 'L07',
#  'September 8, 2023': 'L08',
#  'September 11, 2023': 'L09',
#  'September 12, 2023': 'L10',
#  'September 13, 2023': 'L11',
#  'September 14, 2023': 'L12',
#  'September 15, 2023': 'L13',
#  'September 18, 2023': 'L14',
#  'September 19, 2023': 'L15',
#  'September 20, 2023': 'L16',
#  'September 21, 2023': 'L17',
#  'September 22, 2023': 'L18',
#  'September 25, 2023': 'L19',
#  'September 26, 2023': 'L20',
#  'September 27, 2023': 'L21',
#  'September 28, 2023': 'L22',
#  'October 2, 2023': 'L23',
#  'October 3, 2023': 'L24',
#  'October 4, 2023': 'L25',
#  'October 5, 2023': 'L26',
#  'October 6, 2023': 'L27',
#  'October 11, 2023': 'L28',
#  'October 12, 2023': 'L29',
#  'October 13, 2023': 'L30',
#  'October 16, 2023': 'L31',
#  'October 17, 2023': 'L32',
# ...

# %%
data
for idx, item in enumerate(data):
    print(idx,item)
    list_id = item["list"]
    list_date = list_dict[list_id]
    review_dict[list_id] = [list_date]
# Out:
# 0 {'date': 'August 30, 2023', 'list': 'L01'}
# 1 {'date': 'August 31, 2023', 'list': 'L02'}
# 2 {'date': 'September 1, 2023', 'list': 'L03'}
# 3 {'date': 'September 4, 2023', 'list': 'L04'}
# 4 {'date': 'September 5, 2023', 'list': 'L05'}
# 5 {'date': 'September 6, 2023', 'list': 'L06'}
# 6 {'date': 'September 7, 2023', 'list': 'L07'}
# 7 {'date': 'September 8, 2023', 'list': 'L08'}
# 8 {'date': 'September 11, 2023', 'list': 'L09'}
# 9 {'date': 'September 12, 2023', 'list': 'L10'}
# 10 {'date': 'September 13, 2023', 'list': 'L11'}
# 11 {'date': 'September 14, 2023', 'list': 'L12'}
# 12 {'date': 'September 15, 2023', 'list': 'L13'}
# 13 {'date': 'September 18, 2023', 'list': 'L14'}
# 14 {'date': 'September 19, 2023', 'list': 'L15'}
# 15 {'date': 'September 20, 2023', 'list': 'L16'}
# 16 {'date': 'September 21, 2023', 'list': 'L17'}
# 17 {'date': 'September 22, 2023', 'list': 'L18'}
# 18 {'date': 'September 25, 2023', 'list': 'L19'}
# 19 {'date': 'September 26, 2023', 'list': 'L20'}
# ...

# %%
for idx, item in enumerate(data):
    list_id = item["list"]
    list_date = list_dict[list_id]
    review_dict[list_id] = [list_date]
    for interval in review_intervals[1:]:
        try:
            review_dict[list_id].append(data[idx+interval]['date'])
        except:
            pass

# %%
list_of_dicts = df.to_dict(orient='records')
list_of_dicts
# Out:
# [{'Name': 'L01', 'Date': 'August 30, 2023'},
#  {'Name': 'L02', 'Date': 'August 31, 2023'},
#  {'Name': 'L03', 'Date': 'September 1, 2023'},
#  {'Name': 'L04', 'Date': 'September 4, 2023'},
#  {'Name': 'L05', 'Date': 'September 5, 2023'},
#  {'Name': 'L06', 'Date': 'September 6, 2023'},
#  {'Name': 'L07', 'Date': 'September 7, 2023'},
#  {'Name': 'L08', 'Date': 'September 8, 2023'},
#  {'Name': 'L09', 'Date': 'September 11, 2023'},
#  {'Name': 'L10', 'Date': 'September 12, 2023'},
#  {'Name': 'L11', 'Date': 'September 13, 2023'},
#  {'Name': 'L12', 'Date': 'September 14, 2023'},
#  {'Name': 'L13', 'Date': 'September 15, 2023'},
#  {'Name': 'L14', 'Date': 'September 18, 2023'},
#  {'Name': 'L15', 'Date': 'September 19, 2023'},
#  {'Name': 'L16', 'Date': 'September 20, 2023'},
#  {'Name': 'L17', 'Date': 'September 21, 2023'},
#  {'Name': 'L18', 'Date': 'September 22, 2023'},
#  {'Name': 'L19', 'Date': 'September 25, 2023'},
#  {'Name': 'L20', 'Date': 'September 26, 2023'},
# ...

# %%
date_dict = dict(zip(df['Date'], df['Name']))
date_dict
# Out:
# {'August 30, 2023': 'L01',
#  'August 31, 2023': 'L02',
#  'September 1, 2023': 'L03',
#  'September 4, 2023': 'L04',
#  'September 5, 2023': 'L05',
#  'September 6, 2023': 'L06',
#  'September 7, 2023': 'L07',
#  'September 8, 2023': 'L08',
#  'September 11, 2023': 'L09',
#  'September 12, 2023': 'L10',
#  'September 13, 2023': 'L11',
#  'September 14, 2023': 'L12',
#  'September 15, 2023': 'L13',
#  'September 18, 2023': 'L14',
#  'September 19, 2023': 'L15',
#  'September 20, 2023': 'L16',
#  'September 21, 2023': 'L17',
#  'September 22, 2023': 'L18',
#  'September 25, 2023': 'L19',
#  'September 26, 2023': 'L20',
#  'September 27, 2023': 'L21',
#  'September 28, 2023': 'L22',
#  'October 2, 2023': 'L23',
#  'October 3, 2023': 'L24',
#  'October 4, 2023': 'L25',
#  'October 5, 2023': 'L26',
#  'October 6, 2023': 'L27',
#  'October 11, 2023': 'L28',
#  'October 12, 2023': 'L29',
#  'October 13, 2023': 'L30',
#  'October 16, 2023': 'L31',
#  'October 17, 2023': 'L32',
# ...

# %%
date_dict = dict(zip(df['Date'], df['Name']))
review_dict = {}
review_list = []
for idx, item in enumerate(list_of_dicts):
    list_id = item["Name"]
    list_date = list_dict[list_id]
    review_dict[list_id] = [list_date]
    for interval in review_intervals[1:]:
        try:
            review_dict[list_id].append(data[idx+interval]['Date'])
        except:
            pass
for list_id, dates in review_dict.items():
    for date_i in dates:
        date_dict[date_i].append(int(list_id[1:]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 15
#      13 for list_id, dates in review_dict.items():
#      14     for date_i in dates:
# ---> 15         date_dict[date_i].append(int(list_id[1:]))
#
# AttributeError: 'str' object has no attribute 'append'

# %%
date_dict
# Out:
# {'August 30, 2023': 'L01',
#  'August 31, 2023': 'L02',
#  'September 1, 2023': 'L03',
#  'September 4, 2023': 'L04',
#  'September 5, 2023': 'L05',
#  'September 6, 2023': 'L06',
#  'September 7, 2023': 'L07',
#  'September 8, 2023': 'L08',
#  'September 11, 2023': 'L09',
#  'September 12, 2023': 'L10',
#  'September 13, 2023': 'L11',
#  'September 14, 2023': 'L12',
#  'September 15, 2023': 'L13',
#  'September 18, 2023': 'L14',
#  'September 19, 2023': 'L15',
#  'September 20, 2023': 'L16',
#  'September 21, 2023': 'L17',
#  'September 22, 2023': 'L18',
#  'September 25, 2023': 'L19',
#  'September 26, 2023': 'L20',
#  'September 27, 2023': 'L21',
#  'September 28, 2023': 'L22',
#  'October 2, 2023': 'L23',
#  'October 3, 2023': 'L24',
#  'October 4, 2023': 'L25',
#  'October 5, 2023': 'L26',
#  'October 6, 2023': 'L27',
#  'October 11, 2023': 'L28',
#  'October 12, 2023': 'L29',
#  'October 13, 2023': 'L30',
#  'October 16, 2023': 'L31',
#  'October 17, 2023': 'L32',
# ...

# %%
date_dict
# Out:
# {'August 30, 2023': [1],
#  'August 31, 2023': [1, 2],
#  'September 1, 2023': [1, 2, 3],
#  'September 4, 2023': [2, 3, 4],
#  'September 5, 2023': [1, 3, 4, 5],
#  'September 6, 2023': [2, 4, 5, 6],
#  'September 7, 2023': [3, 5, 6, 7],
#  'September 8, 2023': [1, 4, 6, 7, 8],
#  'September 11, 2023': [2, 5, 7, 8, 9],
#  'September 12, 2023': [3, 6, 8, 9, 10],
#  'September 13, 2023': [4, 7, 9, 10, 11],
#  'September 14, 2023': [5, 8, 10, 11, 12],
#  'September 15, 2023': [6, 9, 11, 12, 13],
#  'September 18, 2023': [7, 10, 12, 13, 14],
#  'September 19, 2023': [8, 11, 13, 14, 15],
#  'September 20, 2023': [1, 9, 12, 14, 15, 16],
#  'September 21, 2023': [2, 10, 13, 15, 16, 17],
#  'September 22, 2023': [3, 11, 14, 16, 17, 18],
#  'September 25, 2023': [4, 12, 15, 17, 18, 19],
#  'September 26, 2023': [5, 13, 16, 18, 19, 20],
#  'September 27, 2023': [6, 14, 17, 19, 20, 21],
#  'September 28, 2023': [7, 15, 18, 20, 21, 22],
#  'October 2, 2023': [8, 16, 19, 21, 22, 23],
# ...

# %%
date_dict
# Out:
# {'August 30, 2023': [1],
#  'August 31, 2023': [1, 2],
#  'September 1, 2023': [1, 2, 3],
#  'September 4, 2023': [2, 3, 4],
#  'September 5, 2023': [1, 3, 4, 5],
#  'September 6, 2023': [2, 4, 5, 6],
#  'September 7, 2023': [3, 5, 6, 7],
#  'September 8, 2023': [1, 4, 6, 7, 8],
#  'September 11, 2023': [2, 5, 7, 8, 9],
#  'September 12, 2023': [3, 6, 8, 9, 10],
#  'September 13, 2023': [4, 7, 9, 10, 11],
#  'September 14, 2023': [5, 8, 10, 11, 12],
#  'September 15, 2023': [6, 9, 11, 12, 13],
#  'September 18, 2023': [7, 10, 12, 13, 14],
#  'September 19, 2023': [8, 11, 13, 14, 15],
#  'September 20, 2023': [1, 9, 12, 14, 15, 16],
#  'September 21, 2023': [2, 10, 13, 15, 16, 17],
#  'September 22, 2023': [3, 11, 14, 16, 17, 18],
#  'September 25, 2023': [4, 12, 15, 17, 18, 19],
#  'September 26, 2023': [5, 13, 16, 18, 19, 20],
#  'September 27, 2023': [6, 14, 17, 19, 20, 21],
#  'September 28, 2023': [7, 15, 18, 20, 21, 22],
#  'October 2, 2023': [8, 16, 19, 21, 22, 23],
# ...

# %%
import pandas as pd
import datetime

# 複習次數對應的間隔時間 (以天為單位)
review_intervals = [0, 1, 2, 4, 7, 15]

review_dict = {}
for idx, item in enumerate(data):
    list_id = item["list"]
    list_date = list_dict[list_id]
    review_dict[list_id] = [list_date]
    for interval in review_intervals[1:]:
        try:
            review_dict[list_id].append(data[idx+interval]['date'])
        except:
            pass
for list_id, dates in review_dict.items():
    read_list = []
    for date_i in dates:
        read_list.append(int(list_id[1:]))
        date_dict[date_i].append(int(list_id[1:]))

review_df = pd.DataFrame(date_dict.items(), columns=["Date", "Review_Lists"])
review_df
# Out:
#                  Date                                       Review_Lists
# 0     August 30, 2023                                       [1, 1, 1, 1]
# 1     August 31, 2023                           [1, 2, 1, 2, 1, 2, 1, 2]
# 2   September 1, 2023               [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# 3   September 4, 2023               [2, 3, 4, 2, 3, 4, 2, 3, 4, 2, 3, 4]
# 4   September 5, 2023   [1, 3, 4, 5, 1, 3, 4, 5, 1, 3, 4, 5, 1, 3, 4, 5]
# ..                ...                                                ...
# 86    January 3, 2024  [72, 80, 83, 85, 86, 87, 72, 80, 83, 85, 86, 8...
# 87    January 4, 2024  [73, 81, 84, 86, 87, 88, 73, 81, 84, 86, 87, 8...
# 88    January 5, 2024  [74, 82, 85, 87, 88, 89, 74, 82, 85, 87, 88, 8...
# 89    January 8, 2024  [75, 83, 86, 88, 89, 90, 75, 83, 86, 88, 89, 9...
# 90    January 9, 2024  [76, 84, 87, 89, 90, 91, 76, 84, 87, 89, 90, 9...
#
# [91 rows x 2 columns]

# %%
review_df['Name']=
